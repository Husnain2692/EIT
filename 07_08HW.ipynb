# %% [markdown]
# <a href="https://colab.research.google.com/github/Husnain2692/EIT/blob/main/07_08HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Check Positive Number
n=int(input('Enter number: '))
if n>0:
    print('Positive')
# Out:
# Enter number: 1
# Positive

# %%
#Check Age 18+
age=int(input("Enter age: "))
if age>=18:
    print("Eligible")
# Out:
# Enter age: 19
# Eligible

# %%
#Check Pass
marks=int(input('Marks: '))
if marks>=40:
    print('Pass')
# Out:
# Marks: 45
# Pass

# %%
#Check Divisible by 5
n=int(input('Enter number: '))
if n%5==0:
    print('Divisible by 5')
# Out:
# Enter number: 20
# Divisible by 5

# %%
#Even or Odd
n=int(input('Enter number: '))
if n%2==0:
    print('Even')
else:
    print('Odd')
# Out:
# Enter number: 4
# Even

# %%
#Positive or Negative
n=int(input('Enter number: '))
if n>=0:
    print('Positive')
else:
    print('Negative')
# Out:
# Enter number: 1
# Positive

# %%
#Largest of Two
a=int(input())
b=int(input())
if a>b:
    print(a)
else:
    print(b)
# Out:
# 25
# 26
# 26

# %%
#Leap Year (Simple)
y=int(input())
if y%4==0:
    print('Leap Year')
else:
    print('Not Leap Year')
# Out:
# 4
# Leap Year

# %%
#Grade
m=int(input())
if m>=80:
    print('A')
elif m>=60:
    print('B')
elif m>=40:
    print('C')
else:
    print('Fail')
# Out:
# 85
# A

# %%
#Week Day
n=int(input())
if n==1:
    print('Monday')
elif n==2:
    print('Tuesday')
elif n==3:
    print('Wednesday')
else:
    print('Other Day')
# Out:
# 5
# Other Day

# %%
# Simple Calculator

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operator (+, -, *, /): ")

if operator == "+":
    print("Result =", num1 + num2)

elif operator == "-":
    print("Result =", num1 - num2)

elif operator == "*":
    print("Result =", num1 * num2)

elif operator == "/":
    print("Result =", num1 / num2)

else:
    print("Invalid operator")
# Out:
# Enter first number: 4
# Enter second number: 2
# Enter operator (+, -, *, /): /
# Result = 2.0

# %%
#Voting Eligibility
age=int(input())
c=input('Citizen yes/no: ')
if age>=18:
    if c=='yes':
        print('Eligible')
    else:
        print('Not Citizen')
else:
    print('Under Age')
# Out:
# 25
# Citizen yes/no: yes
# Eligible

# %%
#Login
user=input('Username: ')
password=input('Password: ')
if user=='admin':
    if password=='1234':
        print('Login Successful')
    else:
        print('Wrong Password')
else:
    print('Wrong Username')
# Out:
# Username: admin
# Password: 1234
# Login Successful

# %%
#Even or Odd
n=int(input())
print('Even' if n%2==0 else 'Odd')
# Out:
# 4
# Even

# %%
#Largest of Two
a=int(input())
b=int(input())
print(a if a>b else b)
# Out:
# 25
# 26
# 26

# %%
a=int(input('First: '))
b=int(input('Second: '))
larger = a if a>b else b
print('Larger number =', larger)
# Out:
# First: 25
# Second: 26
# Larger number = 26

# %%
#Pass or Fail
m=int(input())
print('Pass' if m>=40 else 'Fail')
# Out:
# 45
# Pass

# %%
#Adult or Child
age=int(input())
print('Adult' if age>=18 else 'Child')
# Out:
# 19
# Adult
